# %%
import os
path=os.getcwd()
jpg_files = [f for f in os.listdir(path) if f.endswith('.png')]

# %%
jpg_files
# Out:
# ['cameraman.png']

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img_0=plt.imread(jpg_files[0])
# %matplotlib inline
plt.imshow(img_0)
plt.show()

# %%
np.min(img_0),np.max(img_0)
# Out:
# (0.0, 1.0)

# %%
img_0.ndim,img_0.shape
# Out:
# (3, (512, 512, 3))

# %%
#img_1.ndim,img_1.shape

# %%
img_0+10
# Out:
# array([[[10.615686, 10.615686, 10.615686],
#         [10.615686, 10.615686, 10.615686],
#         [10.623529, 10.623529, 10.623529],
#         ...,
#         [10.592157, 10.592157, 10.592157],
#         [10.592157, 10.592157, 10.592157],
#         [10.592157, 10.592157, 10.592157]],
#
#        [[10.607843, 10.607843, 10.607843],
#         [10.615686, 10.615686, 10.615686],
#         [10.615686, 10.615686, 10.615686],
#         ...,
#         [10.592157, 10.592157, 10.592157],
#         [10.592157, 10.592157, 10.592157],
#         [10.592157, 10.592157, 10.592157]],
#
#        [[10.615686, 10.615686, 10.615686],
#         [10.615686, 10.615686, 10.615686],
#         [10.607843, 10.607843, 10.607843],
#         ...,
#         [10.6     , 10.6     , 10.6     ],
#         [10.592157, 10.592157, 10.592157],
#         [10.592157, 10.592157, 10.592157]],
#
#        ...,
#
#        [[10.478432, 10.478432, 10.478432],
#         [10.470589, 10.470589, 10.470589],
#         [10.494118, 10.494118, 10.494118],
#         ...,
#         [10.478432, 10.478432, 10.478432],
#         [10.447059, 10.447059, 10.447059],
#         [10.431373, 10.431373, 10.431373]],
#
#        [[10.470589, 10.470589, 10.470589],
#         [10.470589, 10.470589, 10.470589],
#         [10.505882, 10.505882, 10.505882],
#         ...,
#         [10.486275, 10.486275, 10.486275],
#         [10.447059, 10.447059, 10.447059],
#         [10.42353 , 10.42353 , 10.42353 ]],
#
#        [[10.486275, 10.486275, 10.486275],
#         [10.470589, 10.470589, 10.470589],
#         [10.494118, 10.494118, 10.494118],
#         ...,
#         [10.470589, 10.470589, 10.470589],
#         [10.439216, 10.439216, 10.439216],
#         [10.439216, 10.439216, 10.439216]]], dtype=float32)

# %%
def my_f_1(a,b):
    assert a>0;" intensity pozitive","error intensity not pozitive"
    if(a<=255-b):
        return a+b
    else:
        return 255
my_f_1(243,30)
# Out:
# 255

# %%
def my_f_2(a):
    #assert a>=0;"intensity positive","error intensity not positive"
    return int(255-a)
my_f_2(234)
# Out:
# 21

# %%
def get_value_from_triple(temp_1):
    #temp_1 = im_1[0,0,:]
    return int(temp_1[0]/3 + temp_1[1]/3+temp_1[2]/3)


def convert_rgb_to_gray_level(im_1):
    m,n,k = im_1.shape
    new = np.zeros((m,n),dtype='uint8')
    for i in range(m):
        for j in range(n):
            new_image=get_value_from_triple(im_1[i,j,:])
            new[i,j]=new_image
    return new

# %%
img_1=convert_rgb_to_gray_level(img_0)
plt.imshow(img_1,cmap='gray')
plt.show()

# %%
m,n=img_1.shape
img_2=np.zeros((m,n),dtype="uint8")

# %%
for i in range(m):
    for j in range(n):
        ## intensity = img_1[i,j]
        ## increment=80
        ## print(intensity)
        ## img_2[i,j]=m_f_1(intensity,increment)
        intensity=img_1[i,j]
        img_2[i,j]=my_f_2(intensity)

# %%
plt.subplot(2,2,1),plt.imshow(img_0,cmap='gray')
plt.subplot(2,2,2),plt.imshow(img_1,cmap='gray')
plt.subplot(2,2,3),plt.imshow(img_2,cmap='gray')
plt.show()

# %%
np.min(img_2),np.max(img_2)
# Out:
# (254, 255)

# %%
x=np.array(list(range(100)))
y1=np.power(x/float(np.max(x)),1)
y2=np.power(x/float(np.max(x)),10)
y3=np.power(x/float(np.max(x)),1/10)

plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)

# %%
x=img_0
img_100=np.power(x/float(np.max(x)),10)
plt.imshow(img_100)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
